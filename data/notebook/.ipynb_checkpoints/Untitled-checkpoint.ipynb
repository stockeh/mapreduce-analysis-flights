# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib as mpl

import seaborn as sns
import numpy as np
import pandas as pd

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

from matplotlib import rc
rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)
plt.style.use('seaborn-whitegrid')

# %%
data = pd.read_csv('../results/global-busiest-airports', sep='\t', names=['iata', 'name', 'count'])
data.head()
# Out:
#   iata                                      name     count
# 0  ORD                                   Chicago  12770733
# 1  ATL  Hartsfield-Jackson Atlanta International  11640188
# 2  DFW           Dallas/Fort Worth International  11080032
# 3  LAX                 Los Angeles International   7891643
# 4  PHX          Phoenix Sky Harbor International   6728818

# %%
fig, ax = plt.subplots(figsize=(6, 3))

data.plot(kind='barh', legend=False, ax=ax)
plt.yticks(range(len(data['name'])), data['name'])
plt.title('Major Hubs', fontsize=11)
plt.grid(True)
plt.xlabel('Number of Flights (million)', fontsize=11)

ax.get_xaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x)/1_000_000, ',')))

plt.savefig('major-hubs.pdf', bbox_inches='tight')
plt.show();

# %%
data = pd.read_csv('../results/global-busiest-airports-by-year', sep='\t', names=['year', 'iata', 'name', 'count'])
data.head()
# Out:
#    year iata                                      name   count
# 0  1987  ORD                                   Chicago  135046
# 1  1987  ATL  Hartsfield-Jackson Atlanta International  133092
# 2  1987  DFW           Dallas/Fort Worth International  104310
# 3  1987  LAX                 Los Angeles International   91243
# 4  1987  DEN                      Denver International   87660

# %%
unique_iata = data.iata.unique()
unique_iata
# Out:
# array(['ORD', 'ATL', 'DFW', 'LAX', 'DEN', 'SFO', 'STL', 'EWR', 'PHX',
#        'PIT', 'LGA', 'DTW', 'CLT', 'MSP', 'IAH', 'BOS', 'SLC', 'CVG',
#        'LAS'], dtype=object)

# %%
unique_year = data.year.unique()
unique_year
# Out:
# array([1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008])

# %%
constant_iata = []

# %%
for i, iata in enumerate(unique_iata):
    empty = False
    for j, year in enumerate(unique_year):
        if data[(data.iata == iata) & (data.year == year)].empty:
            empty = True
#             data.loc[len(data)] = [year, iata, '', 0]
    if not empty:
        constant_iata.append(iata)

constant_iata
# Out:
# ['ORD', 'ATL', 'DFW', 'LAX', 'DEN', 'PHX']

# %%
fig, ax = plt.subplots(figsize=(8, 3))


for i, n in enumerate(constant_iata):
    data[(data.iata == n)].plot(x='year', y='count', label=n, ax=ax, lw=1.5, style='.-')
    
plt.xticks(range(1987, 2009), unique_year, fontsize=9)
plt.title('Major Hubs by Year', fontsize=11)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel('years', fontsize=11)
plt.ylabel('Number of Flights', fontsize=11)

plt.savefig('major-hubs-by-year.pdf', bbox_inches='tight')
plt.show()

# %%
data = pd.read_csv('../results/weather-delays-by-city', sep='\t', names=['city', 'count'])
data.head()

fig, ax = plt.subplots(figsize=(6, 3))


data.plot(kind='barh', legend=False, ax=ax)
plt.yticks(range(len(data['city'])), data['city'])
plt.title('Weather Delays by City', fontsize=11)
plt.grid(True)
plt.xlabel('Number of Delays (thousand)', fontsize=11)

ax.get_xaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x)/1_000, ',')))

plt.savefig('top-weather-delays.pdf', bbox_inches='tight')
plt.show();

# %%
data = pd.read_csv('../results/carrier-top-n-delays', sep='\t', names=['code', 'name', 'val'])

fig, ax = plt.subplots(figsize=(6, 3))

data.plot(kind='barh', legend=False, ax=ax)
plt.yticks(range(len(data['name'])), data['name'])
plt.title('Total Delays', fontsize=11)
plt.grid(True)
plt.xlabel('Number of Delays (thousand)', fontsize=11)

ax.get_xaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x)/1_000, ',')))

plt.savefig('carrier-top-n-delays.pdf', bbox_inches='tight')
plt.show();

# %%
data = pd.read_csv('../results/carrier-top-acc-delays', sep='\t', names=['code', 'name', 'val'])

fig, ax = plt.subplots(figsize=(6, 3))

data.plot(kind='barh', legend=False, ax=ax)
plt.yticks(range(len(data['name'])), data['name'])
plt.title('Delay Times', fontsize=11)
plt.grid(True)
plt.xlabel('Delay in Minutes (million)', fontsize=11)

ax.get_xaxis().set_major_formatter(
    mpl.ticker.FuncFormatter(lambda x, p: format(int(x)/1_000_000, ',')))

plt.savefig('carrier-top-acc-delays.pdf', bbox_inches='tight')
plt.show();

# %%
data = pd.read_csv('../results/carrier-top-avg-delays', sep='\t', names=['code', 'name', 'val'])

fig, ax = plt.subplots(figsize=(6, 3))

data.plot(kind='barh', legend=False, ax=ax)
plt.yticks(range(len(data['name'])), data['name'])
plt.title('Average Delay', fontsize=11)
plt.grid(True)
plt.xlabel('Delay in Minutes', fontsize=11)

plt.savefig('carrier-top-avg-delays.pdf', bbox_inches='tight')
plt.show();
